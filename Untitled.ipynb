# %%
import matplotlib.image as mpimg
import matplotlib.pyplot as plt

# %%
img=mpimg.imread("SOUNAK.jpg",0)

# %%
plt.imshow(img)

# %%
print(img)
# Out:
# [[[121 184 255]
#   [121 184 255]
#   [121 184 255]
#   ...
#   [121 184 255]
#   [121 184 255]
#   [121 184 255]]
#
#  [[121 184 255]
#   [121 184 255]
#   [121 184 255]
#   ...
#   [121 184 255]
#   [121 184 255]
#   [121 184 255]]
#
#  [[121 184 255]
#   [121 184 255]
#   [121 184 255]
#   ...
#   [121 184 255]
#   [121 184 255]
#   [121 184 255]]
#
#  ...
#
#  [[255 255 255]
#   [255 255 255]
#   [255 255 255]
#   ...
#   [255 255 255]
#   [255 255 255]
#   [255 255 255]]
#
#  [[255 255 255]
#   [255 255 255]
#   [255 255 255]
#   ...
#   [255 255 255]
#   [255 255 255]
#   [255 255 255]]
#
#  [[166 166 166]
#   [166 166 166]
#   [166 166 166]
#   ...
#   [166 166 166]
#   [166 166 166]
#   [166 166 166]]]
